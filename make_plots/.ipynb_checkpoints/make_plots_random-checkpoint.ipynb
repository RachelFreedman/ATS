# %%
using Plots, Statistics, NaNStatistics, LinearAlgebra, Serialization, ParticleFilters, StatsBase

include("../utils/import.jl")
using .Import
using ..Import: State

include("../utils/figs.jl")
using .Figs

# %% [markdown]
# # Experiments
#
# ## Conditions
#
# **Active Teacher Selection (ATS):** Solve using an approximate POMDP solver (POMCPOW).
#
# **Random:** Select actions randomly.
#
# **Passive Teacher Selection:** Decide when to select an arm and when to query a teacher using an approximate POMDP solver, but select teacher to query randomly.
#
# ## Run Script
#
#     experiment_scripts/run_exp_random.sh:
#     julia baselines_random.jl 3 3 0.9 7 7 5 1000 289506
#     julia baselines_random.jl 3 3 0.9 7 7 5 1000 289513
#     julia baselines_random.jl 3 3 0.9 7 7 5 1000 289520
#     julia baselines_random.jl 3 3 0.9 7 7 5 1000 292312
#     julia baselines_random.jl 3 3 0.9 7 7 5 1000 292319
#
#     julia ApproximatePOMDP.jl 3 3 0.9 7 7 5 1000 289506
#     julia ApproximatePOMDP.jl 3 3 0.9 7 7 5 1000 289513
#     julia ApproximatePOMDP.jl 3 3 0.9 7 7 5 1000 289520
#     julia ApproximatePOMDP.jl 3 3 0.9 7 7 5 1000 292312
#     julia ApproximatePOMDP.jl 3 3 0.9 7 7 5 1000 292319

# %% [markdown]
# # Plots
# ## Set Parameters
# ### Experiment Names

# %%
pomdp_expIDs = ["221117_"*x for x in ["145355", "150543", "151923", "153210"]]
random_expIDs = ["base_naive_221117_"*x for x in ["145245", "14533", "145321", "145339"]]
passive_expIDs = ["base_naive_221117_"*x for x in ["145245", "14533", "145321", "145339"]];

# %% [markdown]
# ### Experiment Parameters

# %%
runs = 10
actions = ["C1", "C2", "C3", "B1", "B2", "B3"]
pomdp_name, random_name, passive_name = "ATS", "Random", "Passive";

# %% [markdown]
# ### Plotting Parameters

# %%
window = 100
labels = [pomdp_name random_name passive_name];

# %% [markdown]
# ## Import Data

# %%
# takes ~3min
@time begin
    println("importing exp="*string(pomdp_name)*" 1 (exp "*pomdp_expIDs[1]*") data...")
    s_p1, t_p1, a_p1, r_p1, beliefs_p1, final_states_p1, avg_belief_p1, avg_belief_u_p1 = Import.import_experiment(pomdp_expIDs[1], runs, "..")
end
@time begin
    println("importing exp="*string(pomdp_name)*" 2 (exp "*pomdp_expIDs[2]*") data...")
    s_p2, t_p2, a_p2, r_p2, beliefs_p2, final_states_p2, avg_belief_p2, avg_belief_u_p2 = Import.import_experiment(pomdp_expIDs[2], runs, "..")
end
@time begin
    println("importing exp="*string(pomdp_name)*" 3 (exp "*pomdp_expIDs[3]*") data...")
    s_p3, t_p3, a_p3, r_p3, beliefs_p3, final_states_p3, avg_belief_p3, avg_belief_u_p3 = Import.import_experiment(pomdp_expIDs[3], runs, "..")
end
@time begin
    println("importing exp="*string(pomdp_name)*" 4 (exp "*pomdp_expIDs[4]*") data...")
    s_p4, t_p4, a_p4, r_p4, beliefs_p4, final_states_p4, avg_belief_p4, avg_belief_u_p4 = Import.import_experiment(pomdp_expIDs[4], runs, "..")
end
@time begin
    println("importing exp="*string(pomdp_name)*" 5 (exp "*pomdp_expIDs[5]*") data...")
    s_p5, t_p5, a_p5, r_p5, beliefs_p5, final_states_p5, avg_belief_p5, avg_belief_u_p5 = Import.import_experiment(pomdp_expIDs[5], runs, "..")
end;
# Out:
# importing exp=POMDP solver1 (exp 221117_145355) data...
#  52.357276 seconds (403.69 M allocations: 15.580 GiB, 4.39% gc time, 1.58% compilation time)
# importing exp=POMDP solver2 (exp 221117_150543) data...
#  50.875081 seconds (398.58 M allocations: 15.317 GiB, 3.92% gc time)
# importing exp=POMDP solver3 (exp 221117_151923) data...
#  51.034481 seconds (398.50 M allocations: 15.316 GiB, 3.45% gc time)
# importing exp=POMDP solver4 (exp 221117_153210) data...
#  51.827202 seconds (398.63 M allocations: 15.316 GiB, 4.19% gc time)

# %%
@time begin
    println("importing exp="*string(random_name)*"1 (exp "*random_expIDs[1]*") data...")
    s_r1, t_r1, a_r1, r_r1 = Import.get_star(naive_expIDs[1], runs, "..")
end
@time begin
    println("importing exp="*string(random_name)*"2 (exp "*random_expIDs[2]*") data...")
    s_r2, t_r2, a_r2, r_r2 = Import.get_star(naive_expIDs[2], runs, "..")
end
@time begin
    println("importing exp="*string(random_name)*"3 (exp "*random_expIDs[3]*") data...")
    s_r3, t_r3, a_r3, r_r3 = Import.get_star(naive_expIDs[3], runs, "..")
end
@time begin
    println("importing exp="*string(random_name)*"4 (exp "*random_expIDs[4]*") data...")
    s_r4, t_r4, a_r4, r_r4 = Import.get_star(naive_expIDs[4], runs, "..")
end
@time begin
    println("importing exp="*string(random_name)*"5 (exp "*random_expIDs[5]*") data...")
    s_r5, t_r5, a_r5, r_r5 = Import.get_star(naive_expIDs[5], runs, "..")
end;
# Out:
# importing exp=Naive solver1 (exp base_naive_221117_145245) data...
#   0.008273 seconds (21.33 k allocations: 2.163 MiB, 30.91% compilation time)
# importing exp=Naive solver2 (exp base_naive_221117_14533) data...
#   0.003285 seconds (20.43 k allocations: 2.113 MiB)
# importing exp=Naive solver3 (exp base_naive_221117_145321) data...
#   0.003114 seconds (20.43 k allocations: 2.113 MiB)
# importing exp=Naive solver4 (exp base_naive_221117_145339) data...
#   0.002795 seconds (20.43 k allocations: 2.062 MiB)

# %%
@time begin
    println("importing exp="*string(passive_name)*"1 (exp "*passive_expIDs[1]*") data...")
    s_pa1, t_pa1, a_pa1, r_pa1 = Import.get_star(naive_expIDs[1], runs, "..")
end
@time begin
    println("importing exp="*string(passive_name)*"2 (exp "*passive_expIDs[2]*") data...")
    s_pa2, t_pa2, a_pa2, r_pa2 = Import.get_star(naive_expIDs[2], runs, "..")
end
@time begin
    println("importing exp="*string(passive_name)*"3 (exp "*passive_expIDs[3]*") data...")
    s_pa3, t_pa3, a_pa3, r_pa3 = Import.get_star(naive_expIDs[3], runs, "..")
end
@time begin
    println("importing exp="*string(passive_name)*"4 (exp "*passive_expIDs[4]*") data...")
    s_pa4, t_pa4, a_pa4, r_pa4 = Import.get_star(naive_expIDs[4], runs, "..")
end
@time begin
    println("importing exp="*string(passive_name)*"5 (exp "*passive_expIDs[5]*") data...")
    s_pa5, t_pa5, a_pa5, r_pa5 = Import.get_star(naive_expIDs[5], runs, "..")
end;

# %%
# combine data across experiments for each condition
t_p = t_p1
s_p = [cat(s_p1, s_p2, s_p3, s_p4, s_p5, dims=1)[runs*i] for i in 1:5]
a_p = cat(a_p1, a_p2, a_p3, a_p4, a_p5, dims=1)
r_p = cat(r_p1, r_p2, r_p3, r_p4, r_p5, dims=1)

t_r = t_r1
s_r = [cat(s_r1, s_r2, s_r3, s_r4, s_r5, dims=1)[runs*i] for i in 1:5]
a_r = cat(a_r1, a_r2, a_r3, a_r4, a_r5, dims=1)
r_r = cat(r_r1, r_r2, r_r3, r_r4, r_r5, dims=1)
;

# %% [markdown]
# ## Analysis
# ### General

# %%
function print_state(s::State)
    println("\t u: ", s.u)
    println("\t d1: ", s.d[1], "\t (exp val ", dot(s.u, s.d[1]), ")")
    println("\t d1: ", s.d[2], "\t (exp val ", dot(s.u, s.d[2]), ")")
    println("\t d1: ", s.d[3], "\t (exp val ", dot(s.u, s.d[3]), ")")
end
# Out:
# print_state (generic function with 1 method)

# %%
# all runs under a given expID have the same start state & optimal action
println("** "*pomdp_name*" condition **")
for i in 1:length(pomdp_expIDs)
    optimal_action, highest_R = Import.get_optimal_arm(s_p[i])

    println("State "*string(i)*":")
    print_state(s_n[i])
    println("Highest-Reward Arm:\t"*string(optimal_action)*" (R="*string(highest_R)*")\n")
end
println("** "*naive_name*" condition **")
for i in 1:length(naive_expIDs)
    optimal_action, highest_R = Import.get_optimal_arm(s_n[i])
    
    println("State "*string(i)*":")
    print_state(s_n[i])
    println("Highest-Reward Arm:\t"*string(optimal_action)*" (R="*string(highest_R)*")\n")
end
# Out:
# ** POMDP solver condition **
# State 1:
# 	 u: [10.0, 1.6666666666666667, 0.0]
# 	 d1: [0.0, 0.6666666666666666, 0.33333333333333337]	 (exp val 1.1111111111111112)
# 	 d1: [0.0, 0.3333333333333333, 0.6666666666666667]	 (exp val 0.5555555555555556)
# 	 d1: [0.0, 0.16666666666666666, 0.8333333333333334]	 (exp val 0.2777777777777778)
# Highest-Reward Arm:	C1 (R=1.1111111111111112)
#
# State 2:
# 	 u: [10.0, 3.3333333333333335, 0.0]
# 	 d1: [0.0, 0.6666666666666666, 0.33333333333333337]	 (exp val 2.2222222222222223)
# 	 d1: [0.0, 0.3333333333333333, 0.6666666666666667]	 (exp val 1.1111111111111112)
# 	 d1: [0.0, 0.16666666666666666, 0.8333333333333334]	 (exp val 0.5555555555555556)
# Highest-Reward Arm:	C1 (R=2.2222222222222223)
#
# State 3:
# 	 u: [8.333333333333334, 5.0, 1.6666666666666667]
# 	 d1: [0.16666666666666666, 0.8333333333333334, 0.0]	 (exp val 5.555555555555555)
# 	 d1: [0.0, 0.3333333333333333, 0.6666666666666667]	 (exp val 2.7777777777777777)
# 	 d1: [0.0, 0.16666666666666666, 0.8333333333333334]	 (exp val 2.2222222222222223)
# Highest-Reward Arm:	C1 (R=5.555555555555555)
#
# State 4:
# 	 u: [8.333333333333334, 6.666666666666667, 1.6666666666666667]
# 	 d1: [0.16666666666666666, 0.8333333333333334, 0.0]	 (exp val 6.944444444444445)
# 	 d1: [0.0, 0.3333333333333333, 0.6666666666666667]	 (exp val 3.3333333333333335)
# 	 d1: [0.0, 0.16666666666666666, 0.8333333333333334]	 (exp val 2.5)
# Highest-Reward Arm:	C1 (R=6.944444444444445)
#
# ** Naive solver condition **
# State 1:
# 	 u: [10.0, 1.6666666666666667, 0.0]
# 	 d1: [0.0, 0.6666666666666666, 0.33333333333333337]	 (exp val 1.1111111111111112)
# 	 d1: [0.0, 0.3333333333333333, 0.6666666666666667]	 (exp val 0.5555555555555556)
# 	 d1: [0.0, 0.16666666666666666, 0.8333333333333334]	 (exp val 0.2777777777777778)
# Highest-Reward Arm:	C1 (R=1.1111111111111112)
#
# State 2:
# 	 u: [10.0, 3.3333333333333335, 0.0]
# 	 d1: [0.0, 0.6666666666666666, 0.33333333333333337]	 (exp val 2.2222222222222223)
# 	 d1: [0.0, 0.3333333333333333, 0.6666666666666667]	 (exp val 1.1111111111111112)
# 	 d1: [0.0, 0.16666666666666666, 0.8333333333333334]	 (exp val 0.5555555555555556)
# Highest-Reward Arm:	C1 (R=2.2222222222222223)
#
# State 3:
# 	 u: [8.333333333333334, 5.0, 1.6666666666666667]
# 	 d1: [0.16666666666666666, 0.8333333333333334, 0.0]	 (exp val 5.555555555555555)
# 	 d1: [0.0, 0.3333333333333333, 0.6666666666666667]	 (exp val 2.7777777777777777)
# 	 d1: [0.0, 0.16666666666666666, 0.8333333333333334]	 (exp val 2.2222222222222223)
# Highest-Reward Arm:	C1 (R=5.555555555555555)
#
# State 4:
# 	 u: [8.333333333333334, 6.666666666666667, 1.6666666666666667]
# 	 d1: [0.16666666666666666, 0.8333333333333334, 0.0]	 (exp val 6.944444444444445)
# 	 d1: [0.0, 0.3333333333333333, 0.6666666666666667]	 (exp val 3.3333333333333335)
# 	 d1: [0.0, 0.16666666666666666, 0.8333333333333334]	 (exp val 2.5)
# Highest-Reward Arm:	C1 (R=6.944444444444445)

# %%
Figs.plot_avg_r_multiple_experiments([r_p, r_n], window, labels, "Average Reward")

# %%
# calc avg scaled reward (scaled to max-R arm)
# by construction, first arm is highest reward
s_n_list = cat(s_n1, s_n2, s_n3, s_n4, dims=1)
s_p_list = cat(s_p1, s_p2, s_p3, s_p4, dims=1)

r_n_scaled = []
for i in 1:length(r_n)
    highest_r = dot(s_n_list[i].u, s_n_list[i].d[1])
    push!(r_n_scaled, r_n[i] ./ highest_r)
end

r_p_scaled = []
for i in 1:length(r_p)
    highest_r = dot(s_p_list[i].u, s_p_list[i].d[1])
    push!(r_p_scaled, r_p[i] ./ highest_r)
end

# %%
Figs.plot_avg_r_multiple_experiments_normalized([r_p_scaled, r_n_scaled], window, labels, "Average Reward (scaled)")

# %%
y = 0.999
Figs.plot_cumulative_avg_r_multiple_experiments([r_p, r_n], y, labels, "Cumulative Discounted (y="*string(y)*") Reward")

# %% [markdown]
# ## Action Distributions

# %%
Figs.plot_proportion_actions_all(a_p, actions, window, "exp="*pomdp_name*" Actions")

# %%
Figs.plot_proportion_actions_all(a_n, actions, window, "exp="*naive_name*" Actions")
